# %%
# !pip install --upgrade mplfinance
# Out:
# ...
#      ---------------------------------------- 71.6/71.6 kB 2.0 MB/s eta 0:00:00
# ...

# %%
# Provides ways to work with large multidimensional arrays
import numpy as np 
# Allows for further data manipulation and analysis
import pandas as pd


from pandas_datareader import data as web # Reads stock data 
import matplotlib.pyplot as plt # Plotting
import matplotlib.dates as mdates # Styling dates
# %matplotlib inline

import datetime as dt # For defining dates
import mplfinance as mpf # Matplotlib finance

import time

# Used to get data from a directory
import os
from os import listdir
from os.path import isfile, join

# %% [markdown]
# ## Массивы для несохраненных данных

# %%
stocks_not_downloaded = []
missing_stocks = []

# %% [markdown]
# # Функция Дата_фрейм из CSV

# %%
# Reads a dataframe from the CSV file, changes index to date and returns it
def get_stock_df_from_csv(folder, ticker, ):
    
    # Try to get the file and if it doesn't exist issue a warning
    try:
        df = pd.read_csv(folder + ticker + '.csv')
    except FileNotFoundError:
        print("File Doesn't Exist")
    else:
        return df

# %% [markdown]
# # Returns a Named Columns Data from a CSV

# %%
def get_column_from_csv(file, col_name):
    # Try to get the file and if it doesn't exist issue a warning
    try:
        df = pd.read_csv(file)
    except FileNotFoundError:
        print("File Doesn't Exist")
    else:
        return df[col_name]

# %% [markdown]
# # Function that Saves Stock Data to CSV

# %%
# Function that gets a dataframe by providing a ticker and starting date
def save_to_csv_from_yahoo(folder, ticker, syear, smonth, sday, eyear, emonth, eday):
    start = dt.datetime(syear, smonth, sday)
    end = dt.datetime(eyear, emonth, eday)
    try:
        print("Get Data for : ", ticker)
        # Get historical closing price data
        df = web.DataReader(ticker, 'yahoo', start, end)['Adj Close']
    
        # Wait 2 seconds
        time.sleep(2)
        
        if df.empty:
            stocks_not_downloaded.append(ticker)
        
        # Remove the period for saving the file name
        # Save data to a CSV file
        # File to save to 
        the_file = folder + ticker.replace(".", "_") + '.csv'
        print(the_file, " Saved")
        df.to_csv(the_file)
    except Exception as ex:
        stocks_not_downloaded.append(ticker)
        print("Couldn't Get Data for :", ticker)

# %% [markdown]
# # СКАЧИВАЕМ NASDAQ

# %%
# # Total of 2968 tickers
tickers = get_column_from_csv(r"C:\Users\koala\Documents\CASE22\Nasdaq.csv", "Ticker")
tickers

for x in tickers:
     print(x, end=", ")
# Out:
# AAIT, AAL, AAME, AAOI, AAON, AAPL, AAVL, AAWW, AAXJ, ABAC, ABAX, ABCB, ABCD, ABCO, ABCW, ABDC, ABGB, ABIO, ABMD, ABTL, ABY, ACAD, ACAS, ACAT, ACET, ACFC, ACFN, ACGL, ACHC, ACHN, ACIW, ACLS, ACNB, ACOR, ACPW, ACRX, ACSF, ACST, ACTA, ACTG, ACTS, ACUR, ACWI, ACWX, ACXM, ADAT, ADBE, ADEP, ADES, ADHD, ADI, ADMA, ADMP, ADMS, ADNC, ADP, ADRA, ADRD, ADRE, ADRU, ADSK, ADTN, ADUS, ADVS, ADXS, ADXSW, AEGN, AEGR, AEHR, AEIS, AEPI, AERI, AETI, AEY, AEZS, AFAM, AFCB, AFFX, AFH, AFMD, AFOP, AFSI, AGEN, AGII, AGIIL, AGIO, AGNC, AGNCB, AGNCP, AGND, AGRX, AGTC, AGYS, AGZD, AHGP, AHPI, AIMC, AINV, AIQ, AIRM, AIRR, AIRT, AIXG, AKAM, AKAO, AKBA, AKER, AKRX, ALCO, ALDR, ALDX, ALGN, ALGT, ALIM, ALKS, ALLB, ALLT, ALNY, ALOG, ALOT, ALQA, ALSK, ALTR, ALXA, ALXN, AMAG, AMAT, AMBA, AMBC, AMBCW, AMCC, AMCF, AMCN, AMCX, AMD, AMDA, AMED, AMGN, AMIC, AMKR, AMNB, AMOT, AMOV, AMPH, AMRB, AMRI, AMRK, AMRN, AMRS, AMSC, AMSF, AMSG, AMSGP, AMSWA, AMTX, AMWD, AMZN, ANAC, ANAD, ANAT, ANCB, ANCI, ANCX, ANDE, ANGI, ANGO, ANI
# ...

# %%
folder = r"C:\Users\koala\Documents\CASE22\STOCKS/"
for x in range(0, 2):
   save_to_csv_from_yahoo(folder, tickers[x], 2017, 10, 13, 2022, 11, 10)
print("Finished")
stocks_not_downloaded
# Out:
# Get Data for :  AAIT
# C:\Users\koala\Documents\CASE22\STOCKS/AAIT.csv  Saved
# Get Data for :  AAL
# C:\Users\koala\Documents\CASE22\STOCKS/AAL.csv  Saved
# Finished
# ['ABAC', 'ABCW', 'ABDC', 'ABGB', 'ABTL']

# %%
folder = r"C:\Users\koala\Documents\CASE22\STOCKS/"
for x in range(2, 500):
   save_to_csv_from_yahoo(folder, tickers[x], 2017, 10, 13, 2022, 11, 10)
print("Finished")
stocks_not_downloaded
# Out:
# Get Data for :  AAME
# C:\Users\koala\Documents\CASE22\STOCKS/AAME.csv  Saved
# Get Data for :  AAOI
# C:\Users\koala\Documents\CASE22\STOCKS/AAOI.csv  Saved
# Get Data for :  AAON
# C:\Users\koala\Documents\CASE22\STOCKS/AAON.csv  Saved
# Get Data for :  AAPL
# C:\Users\koala\Documents\CASE22\STOCKS/AAPL.csv  Saved
# Get Data for :  AAVL
# C:\Users\koala\Documents\CASE22\STOCKS/AAVL.csv  Saved
# Get Data for :  AAWW
# C:\Users\koala\Documents\CASE22\STOCKS/AAWW.csv  Saved
# Get Data for :  AAXJ
# C:\Users\koala\Documents\CASE22\STOCKS/AAXJ.csv  Saved
# Get Data for :  ABAC
# Couldn't Get Data for : ABAC
# Get Data for :  ABAX
# C:\Users\koala\Documents\CASE22\STOCKS/ABAX.csv  Saved
# Get Data for :  ABCB
# C:\Users\koala\Documents\CASE22\STOCKS/ABCB.csv  Saved
# Get Data for :  ABCD
# C:\Users\koala\Documents\CASE22\STOCKS/ABCD.csv  Saved
# Get Data for :  ABCO
# C:\Users\koala\Documents\CASE22\STOCKS/ABCO.csv  Saved
# Get Data for :  ABCW
# Couldn't Get Data for : ABCW
# ...

# %%
folder = r"C:\Users\koala\Documents\CASE22\STOCKS/"
for x in range(500, 1000):
   save_to_csv_from_yahoo(folder, tickers[x], 2017, 10, 13, 2022, 11, 10)
print("Finished")
stocks_not_downloaded
# Out:
# Get Data for :  CERS
# C:\Users\koala\Documents\CASE22\STOCKS/CERS.csv  Saved
# Get Data for :  CERU
# Couldn't Get Data for : CERU
# Get Data for :  CETV
# Couldn't Get Data for : CETV
# Get Data for :  CEVA
# C:\Users\koala\Documents\CASE22\STOCKS/CEVA.csv  Saved
# Get Data for :  CFA
# C:\Users\koala\Documents\CASE22\STOCKS/CFA.csv  Saved
# Get Data for :  CFBK
# C:\Users\koala\Documents\CASE22\STOCKS/CFBK.csv  Saved
# Get Data for :  CFFI
# C:\Users\koala\Documents\CASE22\STOCKS/CFFI.csv  Saved
# Get Data for :  CFFN
# C:\Users\koala\Documents\CASE22\STOCKS/CFFN.csv  Saved
# Get Data for :  CFGE
# Couldn't Get Data for : CFGE
# Get Data for :  CFNB
# C:\Users\koala\Documents\CASE22\STOCKS/CFNB.csv  Saved
# Get Data for :  CFNL
# Couldn't Get Data for : CFNL
# Get Data for :  CFO
# C:\Users\koala\Documents\CASE22\STOCKS/CFO.csv  Saved
# Get Data for :  CFRX
# C:\Users\koala\Documents\CASE22\STOCKS/CFRX.csv  Saved
# Get Data for :  CFRXW
# Couldn't Get Data for : CFRXW
# ...

# %%
folder = r"C:\Users\koala\Documents\CASE22\STOCKS/"
for x in range(1500, 2000):
   save_to_csv_from_yahoo(folder, tickers[x], 2017, 10, 13, 2022, 11, 10)
print("Finished")
stocks_not_downloaded
# Out:
# Get Data for :  KEYW
# C:\Users\koala\Documents\CASE22\STOCKS/KEYW.csv  Saved
# Get Data for :  KFFB
# C:\Users\koala\Documents\CASE22\STOCKS/KFFB.csv  Saved
# Get Data for :  KFRC
# C:\Users\koala\Documents\CASE22\STOCKS/KFRC.csv  Saved
# Get Data for :  KFX
# Couldn't Get Data for : KFX
# Get Data for :  KGJI
# C:\Users\koala\Documents\CASE22\STOCKS/KGJI.csv  Saved
# Get Data for :  KIN
# Couldn't Get Data for : KIN
# Get Data for :  KINS
# C:\Users\koala\Documents\CASE22\STOCKS/KINS.csv  Saved
# Get Data for :  KIRK
# C:\Users\koala\Documents\CASE22\STOCKS/KIRK.csv  Saved
# Get Data for :  KITE
# Couldn't Get Data for : KITE
# Get Data for :  KLAC
# C:\Users\koala\Documents\CASE22\STOCKS/KLAC.csv  Saved
# Get Data for :  KLIC
# C:\Users\koala\Documents\CASE22\STOCKS/KLIC.csv  Saved
# Get Data for :  KLXI
# C:\Users\koala\Documents\CASE22\STOCKS/KLXI.csv  Saved
# Get Data for :  KMDA
# C:\Users\koala\Documents\CASE22\STOCKS/KMDA.csv  Saved
# Get Data for :  KNDI
# ...

# %%
folder = r"C:\Users\koala\Documents\CASE22\STOCKS/"
for x in range(2500, 2968):
   save_to_csv_from_yahoo(folder, tickers[x], 2017, 10, 13, 2022, 11, 10)
print("Finished")
stocks_not_downloaded
# Out:
# Get Data for :  SQNM
# Couldn't Get Data for : SQNM
# Get Data for :  SQQQ
# C:\Users\koala\Documents\CASE22\STOCKS/SQQQ.csv  Saved
# Get Data for :  SRCE
# C:\Users\koala\Documents\CASE22\STOCKS/SRCE.csv  Saved
# Get Data for :  SRCL
# C:\Users\koala\Documents\CASE22\STOCKS/SRCL.csv  Saved
# Get Data for :  SRDX
# C:\Users\koala\Documents\CASE22\STOCKS/SRDX.csv  Saved
# Get Data for :  SREV
# Couldn't Get Data for : SREV
# Get Data for :  SRNE
# C:\Users\koala\Documents\CASE22\STOCKS/SRNE.csv  Saved
# Get Data for :  SRPT
# C:\Users\koala\Documents\CASE22\STOCKS/SRPT.csv  Saved
# Get Data for :  SRSC
# Couldn't Get Data for : SRSC
# Get Data for :  SSB
# C:\Users\koala\Documents\CASE22\STOCKS/SSB.csv  Saved
# Get Data for :  SSBI
# C:\Users\koala\Documents\CASE22\STOCKS/SSBI.csv  Saved
# Get Data for :  SSFN
# Couldn't Get Data for : SSFN
# Get Data for :  SSH
# Couldn't Get Data for : SSH
# Get Data for :  SSNC
# C:\Users\koala\Documents\CASE22\STOCKS/SSNC.csv  Saved
# ...

# %%
len(stocks_not_downloaded)
# Out:
# 833
